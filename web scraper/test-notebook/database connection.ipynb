# %%
import psycopg2

#establishing the connection
conn = psycopg2.connect (
   database="index", user='postgres', password='3214', host='127.0.0.1', port= '5432'
)
conn.autocommit = True
 
# Creating a cursor object
cursor = conn.cursor()
 
# query to create a database
sql = "CREATE database Index" 
 
# executing above query 
cursor.execute(sql)
print("Database has been created successfully !!")
 
# Closing the connection
conn.close()

# %%
import psycopg2

#establishing the connection
conn = psycopg2.connect (
   database="index", user='postgres', password='3214', host='127.0.0.1', port= '5432'
)
conn.autocommit = True
 
# Creating a cursor object
cursor = conn.cursor()
 
# query to create a database
sql = "CREATE TABLE index (id SERIAL,title VARCHAR(250),page_link VARCHAR(500),thumbnail VARCHAR(500), PRIMARY KEY (id))"
 
# executing above query 
cursor.execute(sql)
print("table has been created successfully !!")
 
# Closing the connection
conn.close()
# Out:
# table has been created successfully !!

# %%
import psycopg2
import os
import csv 

#establishing the connection
conn = psycopg2.connect (
   database="index", user='postgres', password='3214', host='127.0.0.1', port= '5432'
)
conn.autocommit = True
 
# Creating a cursor object
cursor = conn.cursor()
 
# query to create a database
csv_file = r'listtocsv1.csv'
folder_add =r'E:\supreme-commander\supreme-commander\web scraper\test-notebook'
csv_file_path = os.path.join(folder_add,csv_file)
#E:\supreme-commander\supreme-commander\web scraper\test-notebook\listtocsv1.csv
#sql = "COPY index(title, page_link, thumbnail) FROM 'E:\\supreme-commander\\supreme-commander\\web scraper\\test-notebook\\demo_csv.csv'  DELIMITER ',' CSV HEADER;"
import csv

insert = 'INSERT INTO index (title, page_link, thumbnail) VALUES( )'
  
# Open file 
with open(csv_file_path) as file_obj:
      
    # Create reader object by passing the file 
    # object to reader method
    reader_obj = csv.reader(file_obj)
      
    # Iterate over each row in the csv 
    # file using reader object
    for row in reader_obj:
        cursor.execute(f"INSERT INTO index (title, page_link, thumbnail) VALUES('{row[0]}','{row[1]}','{row[2]}')")
        
# executing above query 
    

print("csv inserted!!")
 
# Closing the connection
conn.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 34
#      31     # Iterate over each row in the csv
#      32     # file using reader object
#      33     for row in reader_obj:
# ---> 34         cursor.execute(f"INSERT INTO index (title, page_link, thumbnail) VALUES('{row[0]}','{row[1]}','{row[2]}')")
#      36 # executing above query
#      39 print("csv inserted!!")
#
# IndexError: list index out of range

# %%
import psycopg2
import os

#establishing the connection
conn = psycopg2.connect (
   database="index", user='postgres', password='3214', host='127.0.0.1', port= '5432'
)
conn.autocommit = True
 
# Creating a cursor object
cursor = conn.cursor()
 
# query 

sql = "SELECT * FROM index;"
 
# executing above query 
cursor.execute(sql)

print(cursor.fetchall())
 
# Closing the connection
conn.close()
# Out:
# [(1, 'Tales of Demons and Gods', 'https://readmanganato.com/manga-ax951880', 'https://avt.mkklcdnv6temp.com/19/v/1-1583464475.jpg'), (2, 'Solo Leveling', 'https://readmanganato.com/manga-dr980474', 'https://avt.mkklcdnv6temp.com/30/a/17-1583496340.jpg'), (3, 'Martial Peak', 'https://readmanganato.com/manga-bn978870', 'https://avt.mkklcdnv6temp.com/20/b/16-1583494192.jpgGIT '), (4, 'Apotheosis', 'https://readmanganato.com/manga-bt978676', 'https://avt.mkklcdnv6temp.com/13/f/16-1583493949.jpg'), (5, 'Versatile Mage', 'https://readmanganato.com/manga-bf979214', 'https://avt.mkklcdnv6temp.com/33/a/16-1583494657.jpg'), (6, 'Star Martial God Technique', 'https://readmanganato.com/manga-wj973392', 'https://avt.mkklcdnv6temp.com/32/i/14-1583490877.jpg'), (7, "A Returner's Magic Should Be Special", 'https://readmanganato.com/manga-ci980191', 'https://avt.mkklcdnv6temp.com/19/m/17-1583495960.jpg'), (8, 'The Beginning After the End', 'https://readmanganato.com/manga-dg980989', 'https://avt.mkkl
# ...

# %%
import psycopg2
import os

#establishing the connection
conn = psycopg2.connect (
   database="index", user='postgres', password='3214', host='127.0.0.1', port= '5432'
)
conn.autocommit = True
 
# Creating a cursor object
cursor = conn.cursor()

cursor.execute("""SELECT relname FROM pg_class WHERE relkind='r'
                  AND relname !~ '^(pg_|sql_)';""") # "rel" is short for relation.

tables = [i[0] for i in cursor.fetchall()] # A list() of tables.

print(cursor.fetchall())
 
# Closing the connection
conn.close()
# Out:
# []

# %%
import psycopg2
import os

#establishing the connection
conn = psycopg2.connect (
   database="index", user='postgres', password='3214', host='127.0.0.1', port= '5432'
)
conn.autocommit = True
 
# Creating a cursor object
cursor = conn.cursor()
 
# query to fetch all tables

sql = "SELECT datname FROM pg_database"
 
# executing above query 
cursor.execute(sql)

print(cursor.fetchall())
 
# Closing the connection
conn.close()
# Out:
# [('template1',), ('template0',), ('index',)]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 34
#      31     # Iterate over each row in the csv
#      32     # file using reader object
#      33     for row in reader_obj:
# ---> 34         print(row+1)
#      35         #cursor.execute(f"INSERT INTO index (title, page_link, thumbnail) VALUES('{row}')")
#      36
#      37 # executing above query
#      40 print("csv inserted!!")
#
# TypeError: can only concatenate list (not "int") to list

# %%
df.to_sql('db_table2', engine, if_exists='replace')

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:3214@127.0.0.1:5432/index')



 
# Skipping 2 rows from start in csv
# and initialize it to a  dataframe
df = pd.read_csv("listtocsv1.csv", skiprows = 1, header=None)
df.columns = ["title","link","thumbnail"]
df['id'] = range(1, len(df) + 1)
df=df.set_index('id')
df.to_sql('listtocsv1.csv', engine, if_exists='replace') #insert dataframe into database


 
# Show the dataframe
df
# Out:
#                                                    title  \
# id
# 1                               Tales of Demons and Gods
# 2                                          Solo Leveling
# 3                                           Martial Peak
# 4                                             Apotheosis
# 5                                         Versatile Mage
# ...                                                  ...
# 35498  7 Nichikan de Shinu Joshikousei to Shinigami n...
# 35499                              Shinigami no Hanayome
# 35500   That Time Only Akari Got Reincarnated as a Slime
# 35501                                     Mikazuki March
# 35502                                     Sayonara Daisy
#
#                                            link  \
# id
# 1      https://readmanganato.com/manga-ax951880
# 2      https://readmanganato.com/manga-dr980474
# 3      https://readmanganato.com/manga-bn978870
# 4      https://readmanganato.com/manga-bt978676
# ...
